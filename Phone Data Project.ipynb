# %% [markdown]
# # Performance of phones in different Regions
#
# ## Introduction
# This data set if from M-kopa. A company that deals with energy and Utility and give different products that they offer on Pay as you go. The company gives different types of products such as phones.The main focus is on the different types of phones that they issue like Samsung and Nokia.
# ## Project Objectives
# - To find out which brand of phones that customers prefer
# - To find out the regions had the highest phone sales
# - To find out which teams sold the highest phone sales
#
# ## Example of the Dataset being worked on
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv("SarahFinal.csv")
Data.head(10)
# Out:
#    Account Number1        ServiceCenter                      Town  \
# 0         21516167    Kamenu Makongeni    SC066 M-KOPA Shop Thika
# 1         34694539               kiambu   SC066 M-KOPA Shop Thika
# 2         32123514               KISUMU  SC006 M-KOPA Shop Kisumu
# 3           916580              Makueni    SC055 M-KOPA Shop Wote
# 4         37666502                Bomet   SC035 M-KOPA Shop Bomet
# 5         30250371                kisii   SC011 M-KOPA Shop Kisii
# 6         26392147  Syokimau-Mulolongo            SC025 Kitengela
# 7         32819994              Homabay  SC043 M-KOPA Shop Katito
# 8         32809356               Kisumu        SC087 M-KOPA Awasi
# 9         22711428                busia   SC018 M-KOPA Shop Busia
#
#                   TsrName                      Phone Model    Team  \
# 0  Abdrizak Hassan Ismael  MK Phone Samsung A21S single v5  Purple
# 1  Abdrizak Hassan Ismael                     Samsung A21S  Purple
# ...

# %%
#Data.drop_duplicates()
Data.isnull().any() # columns with null values
#Data.head(10)
# Out:
# Account Number1    False
# ServiceCenter      False
# Town               False
# TsrName            False
# Phone Model        False
# Team               False
# Plan Sold          False
# Cluster            False
# Sale Status        False
# Product            False
# Interested         False
# Buy                False
# dtype: bool

# %%
#Data.info()
#Data.info()
#Data_dropped=pd.DataFrame(Data.drop(Data.columns[[1,4,10,11]], axis=1, inplace=True))
#Data_dropped.head()
Data_drop=pd.DataFrame(Data.iloc[:, [0,2,3,5,6]])
print(Data_drop.head())
# Out:
#    Account Number1                      Town                 TsrName    Team  \
# 0         21516167   SC066 M-KOPA Shop Thika  Abdrizak Hassan Ismael  Purple
# 1         34694539   SC066 M-KOPA Shop Thika  Abdrizak Hassan Ismael  Purple
# 2         32123514  SC006 M-KOPA Shop Kisumu  Abdrizak Hassan Ismael  Purple
# 3           916580    SC055 M-KOPA Shop Wote  Abdrizak Hassan Ismael  Purple
# 4         37666502   SC035 M-KOPA Shop Bomet           Brenda Mudola  Orange
#
#                               Plan Sold
# 0       MK +Phone Nokia G21 4/64 CSTR 1
# 1       MK +Phone Nokia G21 4/64 CSTR 1
# 2       MK +Phone Nokia G21 4/64 CSTR 1
# 3       MK +Phone Nokia G21 4/64 CSTR 1
# 4  MK +Phone Samsung A04S 4/64 CSTR1 v1

# %% [markdown]
# # To find out which teams sold the highest phone sales

# %%
#Answering Objective three-To Find Out Which Teams Sold The Highest Phone Sales
team_numbers=Data_drop['Team'].value_counts()
print(team_numbers)
# Out:
# Black     8
# Purple    7
# Orange    5
# White     4
# Brown     1
# Maroon    1
# Name: Team, dtype: int64

# %%
team_numbers=(Data_drop['Team'].value_counts()).to_numpy()
print(np.sum(team_numbers))
print(team_numbers)
plt.pie(team_numbers,labels=["Black","Purple","Orange","White","Brown","Maroon"],autopct="%1.2f%%",
       explode=[0.2,0,0,0,0.2,0.2])
plt.show()
# Black contributed the highest phone sales compared to Maroon and Brown which contributed the lowest phone sales
# Out:
# 26
# [8 7 5 4 1 1]

# %% [markdown]
# # Finding out which brand of phones customers prefer

# %%
#Answering Objective one-To Find Out Which Brand Of Phones Customers Prefer
phonemodel_numbers=Data_drop['Plan Sold'].value_counts()
print(phonemodel_numbers)
# Out:
# MK +Phone Nokia G21 4/64 CSTR 1            10
# MK +Phone Samsung A03 Core 2/32 v14         5
# MK +Phone Nokia C31 4/64 v1                 4
# MK +Phone Nokia G21 4/64 CSTR 1 v3          2
# MK +Phone Samsung A04S 4/64 CSTR1 v1        1
# MK +Phone Samsung A03 Core 2/32  DS v16     1
# MK +Phone Nokia G21 4/64 CSTR 2 v3          1
# MK +Phone Samsung A03 Core 2/32 v15         1
# MK +Phone Samsung A23 4/64 CSTR1 v2         1
# Name: Plan Sold, dtype: int64

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.gca()
Data_drop['Plan Sold'].hist(grid=False, edgecolor='black', ax=ax,bins=8)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Regions with the highest number of phone sales

# %%
#Answering Objective Two-To Find Out Regions That Had The Highest Number Of Phone Sales
Region=Data_drop['Town'].value_counts()
print(Region)
# Out:
# SC066 M-KOPA Shop Thika        2
# SC002 M-KOPA Shop Kilifi       2
# SC055 M-KOPA Shop Wote         2
# SC035 M-KOPA Shop Bomet        2
# SC093 Loita Street CBD         2
# SC005 M-KOPA Shop Migori       2
# SC020 M-KOPA Shop Machakos     1
# SC065 M-KOPA Shop Emali        1
# SC003 Eldoret M-Kopa Office    1
# SC033 M-KOPA Molo              1
# SC023 M-KOPA Shop Nakuru       1
# SC009 M-KOPA Kapsabet shop     1
# SC007 M-KOPA Shop  Kitale      1
# SC006 M-KOPA Shop Kisumu       1
# SC018 M-KOPA Shop Busia        1
# SC087 M-KOPA Awasi             1
# SC043 M-KOPA Shop Katito       1
# SC025 Kitengela                1
# SC011 M-KOPA Shop Kisii        1
# SC080 M-KOPA Kadongo           1
# Name: Town, dtype: int64

# %%
Region=(Data_drop['Town'].value_counts()).to_numpy()
print(np.sum(Region))
# Out:
# 26

# %%
Data_drop.Town.value_counts().plot(kind='bar')
plt.xlabel("Town")
plt.ylabel("Plan Sold")
plt.title('Performance of Towns and Sales Contributed', fontsize=12)
plt.show()

# %%
Data_drop_cut=Data_drop.select_dtypes(["object"]).columns
Data_drop[Data_drop_cut]=Data_drop[Data_drop_cut].apply(lambda x: pd.factorize(x)[0])
Data_dropcorr=Data_drop.corr()
print(Data_dropcorr)
fig=plt.figure(figsize=(8,8))
plot=sns.heatmap(Data_drop.corr().round(2),annot=True,cmap="Purples",mask=np.triu(Data_dropcorr))
plot.set_title("Regions with the most phones sold")
plt.show()
# In summary, sales from agents depends on the region
# Out:
#                  Account Number1      Town   TsrName      Team  Plan Sold
# Account Number1         1.000000 -0.158566 -0.000994 -0.196633  -0.091106
# Town                   -0.158566  1.000000  0.764962  0.522465   0.173845
# TsrName                -0.000994  0.764962  1.000000  0.351313   0.445058
# Team                   -0.196633  0.522465  0.351313  1.000000   0.265581
# Plan Sold              -0.091106  0.173845  0.445058  0.265581   1.000000

# %% [markdown]
# ## This project has also been shared on Github and you can access it via the below link

# %% [markdown]
# https://github.com/sarah52/PROJECT/blob/21d90be3a58fa2006be13e6ba5ca7e63baf7587d/Phone%20Data%20Project.ipynb
